# %%
#wap ask the user
# take a salary : 100000
# take a tax percentage : 10
# find the tax
# formula: salary*tax_per/100

salary=100000
tax_percentage=10
tax_amount=100000*10/100
tax_amount
# Out:
# 10000.0

# %% [markdown]
# # data types
#
# - int
#
# - float
#
# - complex
#
# - str
#
# - list
#
# - tuple
#
# - dict
#
# - set
#
# - frozenset
#
# - range
#
# - bytes
#
# - bytearray
#
# - memoryview
#
# - bool

# %% [markdown]
#  # integer data type

# %%
number=100
type(number)
# Out:
# int

# %% [markdown]
# # float data type

# %%
n1=10.5
type(n1)
# Out:
# float

# %% [markdown]
# ** Exponential Representation

# %%
print(1e1)  # 1*10    
print(1e2)  #1*100
print(2e3)  #1*1000
# Out:
# 10.0
# 100.0
# 2000.0

# %%
print(1e1,1e+1)  #1*10
print(1e2,1e+2)  #1*100
print(2e3,2e+3)  #2*1000
# Out:
# 10.0 10.0
# 100.0 100.0
# 2000.0 2000.0

# %%
2e3 # 2*<number  zeros>  2*10^3
1e1 # 1*10^1
1e1=====can also write as 1e+1
2e3=====can also write as 2e+3
4e5=====can also write as 4e+5

# %%
1e+1 #1*10
1e-1#1/10
# Out:
# 0.1

# %%
2e+3 #2*1000
2e-3 #2/1000
# Out:
# 0.002

# %% [markdown]
# # string data type

# %%
hyderabad=100
print(hyderabad)
# Out:
# 100

# %%
# variable===black
#keyword==== green colour
#string====== red
name='naresh it'
institute_name='naresh it'
coaching_center='omkar sir'
coaching_center
# Out:
# 'omkar sir'

# %%
institute_name
# Out:
# 'naresh it'

# %%
coaching_center
# Out:
# 'naresh it'

# %%
print(name)
# Out:
# naresh it

# %%
print(institute_name)
# Out:
# naresh it

# %%
print(coaching_center)
# Out:
# naresh it

# %%
name1='Naresh IT'
name2='naresh it@gmail.com'
name3='naresh it123'

# %%
name1
# Out:
# 'Naresh IT'

# %%
print(name1)
# Out:
# Naresh IT

# %%
greet1='hello'
greet2=' hello'
greet3='    hello'
print('hello')
print("  hello")
greet1
# Out:
# hello
#   hello
# 'hello'

# %%
print(greet1)
# Out:
# hello

# %%
print(greet2)
# Out:
#  hello

# %%
greet1,greet2
# Out:
# ('hello', ' hello')

# %%
len(greet1),len(greet2)
# Out:
# (5, 6)

# %%
print("greet1")
print(greet2)
print(greet3)
# Out:
# greet1
#  hello
#     hello

# %% [markdown]
# # double quotes

# %%
name1="hyderabad"  #single and double quotyes both are same ,no difference
name1
# Out:
# 'hyderabad'

# %%
print(name1)
# Out:
# hyderabad

# %%
s1="I joined in DS and AI class"
s2='I joined in DS and AI calss' 

#above statement is a information
#information in english
#red colour=====.quotes
#single or double

# %%
s1
# Out:
# 'I joined in DS and AI class'

# %%
s2
# Out:
# 'I joined in DS and AI calss'

# %%
s1="i joined 'da and ai' class"
s1
# Out:
# "i joined 'da and ai' class"

# %%
print(s1)
# Out:
# i joined 'da and ai' class

# %%
print(s1)
print(s2)
# Out:
# i joined 'da and ai' class
# I joined in DS and AI calss

# %%
s1='I joined in "DS and AI" class'
s1
# Out:
# 'I joined in "DS and AI" class'

# %%
print(s1)
# Out:
# I joined in "DS and AI" class

# %%
s2= "I joined in'ds and ai' class"
s2
# Out:
# "I joined in'ds and ai' class"

# %%
print(s2)
# Out:
# I joined in'ds and ai' class

# %% [markdown]
# # triple quoutes

# %% [markdown]
# - in jupyter note book we have a **markdown** option to write a information
#
# - **markdown** means we are conveying some infromation to the user
#
# - but in other platform like **vscode pycharm** we dont have markdown option
#
# - we can convey the information using **TRIPLE QUOTES**
#
# - thi is also called **DOC STRING**
#
# - the code part we provide single or double quotes
#
# - but conveying the information about code is **triple QUOTES**
#
# - **triple quotes** are using in prompt engineering

# %% [markdown]
# **Boolean**
#
# - when we ask the question to machine
#
# - machine always provide only two answers
#
#            - true
#            - flase
#    - true means 1
#    - false means 0
#
# - you can think in another true means ON false means OFF

# %%
on=True
type(on)
# Out:
# bool

# %%
off=(False)
type(off)
# Out:
# bool

# %% [markdown]
# true # variable
# 'true' # string
# True # bool

# %%
True=10
'true'=true
'true'=True
'true'
# Out:
#   Cell In[67], line 1
#     True=10
#     ^
# SyntaxError: cannot assign to True

# %% [markdown]
# **print is a inbuilt function used to print outputs**
#
# - we always work towards only one end goal:*customer satisfaction**
#
# - client does not know the python code
#
# - whatever we want to show the output we need to display very clearly
#
# - Question yourself:**AM I SHOWING OUTPUT PROPERLY**

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the sumation of 100 and 200 is 300')
# Out:
# the addition of 100 and 200 is 300
# the sumation of 100 and 200 is 300

# %%
# rules
#1 the writen : string qyotes (red)
#2 1000 and 2000,100 or 200
# stored in variable n1 and n2 (black)

# %%
n1=100
n2=200
add=n1+n2
print(add) 
print('the addition of 100 and 200 is 300')
print('the summation of 100 and 200 is 300')
# Out:
# the addition of 100 and 200 is 300
# the summation of 100 and 200 is 300

# %%
n1=1000
n2=2000
add=n1+n2
print(n1+n2)
print('the addition of',n1,'and',n2,'is',add)
# Out:
# 3000
# the addition of 1000 and 2000 is 3000

# %%
print('hai')
print('hello')
print('hai,hello')
print('hai,hello,a')
a=100
print('hai,hello,a')
# Out:
# hai
# hello
# hai,hello
# hai,hello,a
# hai,hello,a

# %%
#name
#age
#place
#iam python 10 years coming from hyderabad
name='python'
age=10
city='hyderabad'
print('my name is python im 10 years old. i came from hyderabad')
print('my name is',name,'iam',age,'year old.i came from',city)
# Out:
# my name is python im 10 years old. i came from hyderabad
# my name is python iam 10 year old.i came from hyderabad

# %%
#sir what if i want to use variable in btw the quotes
type('nama')
# Out:
# str

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the addition of {} and {} is {}')
print('the addition of {} and {} id {}'.format(n1,n2,add))
# Out:
# the addition of 100 and 200 is 300
# the addition of {} and {} is {}
# the addition of 100 and 200 id 300

# %%
name='python'
age=10
city='hyderabad'
print('my name is python im 10 years old. i came from hyderabad')
print('my name is',name,'iam',age,'year old.i came from',city)
# Out:
# my name is python im 10 years old. i came from hyderabad
# my name is python iam 10 year old.i came from hyderabad

# %% [markdown]
# **f-string**
# - very very easy and most used method

# %%
n1=100
n2=200
add=n1+n2
print('the addition of 100 and 200 is 300')
print('the addition of {} and {} is {}')
print('the addition of {n1} and {n2} is {add}')
print(f'the addition of {n1} and {n2} is {add}')
# Out:
# the addition of 100 and 200 is 300
# the addition of {} and {} is {}
# the addition of {n1} and {n2} is {add}
# the addition of 100 and 200 is 300

# %% [markdown]
# **questions**

# %%
n1=100
n2=200
add=n1+n2
sub=n1-n2
div=n1/n2
print('the addition of {} and {} is {}'.format(n1,n2,add))
print(f'the substraction of {n1} and {n2} is {sub}')
print(f'the division of{n1} and {n2} is {div}')
print('the substraction of {} and {} is {}'.format(n1,n2,sub))
# Out:
# the addition of 100 and 200 is 300
# the substraction of 100 and 200 is -100
# the division of100 and 200 is 0.5
# the substraction of 100 and 200 is -100

# %%
pi=3.4
radius=100
area_of_circle=pi*radius*radius
print(f'the area of circle is : {area_of_circle}')
# Out:
# the area of circle is : 34000.0

# %%
print('the area of circle is'.formate(area_of_circle))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print('the area of circle is'.formate(area_of_circle))
#
# AttributeError: 'str' object has no attribute 'formate'

# %%
print(f'the area of circle is :{}'{area_of_circle}'))
# Out:
#   Cell In[20], line 1
#     print(f'the area of circle is : {}'{area_of_circle}'))
#                                                        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('the area of circle is : {}'.format(area_of_circle))
# Out:
# the area of circle is : 34000.0

# %%
print('the area of circle is : {}'.format(area_of_circle))
# Out:
# the area of circle is : 34000.0

# %%
print(f'the area of circle is : {area_of_circel}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(f'the area of circle is : {area_of_circel}')
#
# NameError: name 'area_of_circel' is not defined

# %%
print(f'the area of circle is : {area_of_circle}')
# Out:
# the area of circle is : 34000.0

# %%
a=10 # 10 is a value assigned in "a"

# %%
'A'=='a'
# Out:
# False

# %%
'A'==a
# Out:
# False

# %% [markdown]
# **Round**

# %%
a=10
b=21
c=30
avg=(a+b+c)/3
avg
# Out:
# 20.333333333333332

# %%
round(10.6789) #10.6 marks
# Out:
# 11

# %%
round(10.432)
# Out:
# 10

# %%
round(10.6789,1)
# 1 indicates after decimal point ony one digit
# 6789====700===7
#10.7
# Out:
# 10.7

# %%
round(10.6789,2)
# 2 indicates after decimal is two digit
# 789====800===8
# Out:
# 10.68

# %%
round(10.4567)
# Out:
# 10

# %%
round(10.4567,3)
# Out:
# 10.457

# %%
a=10
b=21
c=30
avg=(a+b+c)/3 
round_avg=round(avg,2)
print(f'the avg of {a},{b},{c} is:{round_avg}')
# Out:
# the avg of 10,21,30 is:20.33

# %%
#inbuilt function
print()
type()
max()
min()
sum()
len()
round()

# %% [markdown]
# #() finction call method
#
# #when you miss the bracket
#
# #it wull indicate two ways
#
# - bound method
#
# - function

# %%
import os
os.getcwd
# then recall we missed the bracets
# Out:
# <function nt.getcwd()>

# %%
name='python'  # hard coded
# we fixed thee value
# we need to ask the user enter any value
# differnt user can use the same code

# %% [markdown]
# **input**

# %%
input
# Out:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x0000026C29395160>>

# %%
input()
# Out:
#  python
# 'python'

# %%
input()
# Out:
#  30
# '30'

# %%
input()
# Out:
#  hyderabad
# 'hyderabad'

# %%
input()
# Out:
#  rajnath
# 'rajnath'

# %%
input()
# Out:
#  Abhinaya
# 'Abhinaya'

# %%
input()
input()
input()
# Out:
#  Rajnath
#  22
#  hyderabad
# 'hyderabad'

# %%
name=input()
age=input()
city=input()
# Out:
#  rajnath
#  22years
#  hyderabad

# %%
name=input()
age=input()
city=input()
print(f'my name is {name},my age is {age}.i came from {city}')
# Out:
#  rajnath
#  22years
#  hyderabad
# my name is rajnath,my age is 22years.i came from hyderabad

# %%
name=input('rajnath')
age=input('22 years')
city=input('hyderabad')
# Out:
# rajnath
# 22 years
# hyderabad

# %%
name=input('enter ypur name')
age=input('enter your age')
city=input('enter your city')

# %%
name=input('enter ypur name:')
age=input('enter your age:')
city=input('enter your city:')
print(f'my name is {name},my age is {age}.i came from {city}')
# Out:
# enter ypur name: Abhinaya
# enter your age: 20 years
# enter your city: badhempally
# my name is Abhinaya,my age is 20 years.i came from badhempally

# %% [markdown]
# **Note**
#
# - when we provid a value from keyword
#
# - by default python takes **string data type**

# %%
n1=input('enter a number:')
n1
# Out:
# enter a number: 100
# '100'

# %%
n1=input('enter a number:')
n1
# Out:
# enter a number: hundred
# 'hundred'

# %%
n1=input('enter a number1')
n2=input('enter a number2')
n1+n2
# Out:
# enter a number1 100
# enter a number2 200
# '100200'

# %%
n1='100'
n2='200'
n1+n2
# Out:
# '100200'

# %% [markdown]
# **type cast**
#
# - convert one data type to another type
#
# - int,float,str,bool
#
# - if a user provide one data type we can able to convert into other data type

# %% [markdown]
# **integer to other data types**

# %%
n1=100
# 100=====> 100.0     # int into float
float(n1)
# Out:
# 100.0

# %%
n1=100
# 100=====> string===='100'
str(n1)
# Out:
# '100'

# %%
n1=100
# 100 =====>bool ===== true
bool(n1)
# Out:
# True

# %%
float(100),str(100),bool(100)
# Out:
# (100.0, '100', True)

# %%
float(-100),str(-100),bool(-100) # true ON something # flase OFF nothing
# Out:
# (-100.0, '-100', True)

# %%
float(0),str(0),bool(0)
# Out:
# (0.0, '0', False)

# %% [markdown]
# **float to other data type**

# %%
int(10.5),str(10.5),bool(10.5)
# Out:
# (10, '10.5', True)

# %%
int(7.8),str(67),bool(7.5)
# Out:
# (7, '67', True)

# %%
int(-7.7),str(-67),bool(7.5)
# Out:
# (-7, '-67', True)

# %%
int(0),str(0),bool(0)
# Out:
# (0, '0', False)

# %% [markdown]
# **string to other data type**

# %%
s1='apple'
s2='100'
s3='10.5'

# %%
int('apple'),float('apple')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 int('apple'),float('apple')
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
int('100'),float('100'),bool('100')
# Out:
# (100, 100.0, True)

# %%
int('10.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 int('10.5')
#
# ValueError: invalid literal for int() with base 10: '10.5'

# %%
float('10.5')  # any number ppl max they will represent float
               # int ========= float
# Out:
# 10.5

# %%
float('100'),float('100.5')
# Out:
# (100.0, 100.5)

# %%
int('100'),int('100.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 int('100'),int('100.5')
#
# ValueError: invalid literal for int() with base 10: '100.5'

# %%
## float has higer proprity then the int
int(50000)
float(50000)
# Out:
# 50000.0

# %%
bool('apple'),bool('100'),bool('100.5')
# Out:
# (True, True, True)

# %%
len(''),bool('')
# Out:
# (0, False)

# %% [markdown]
# 0====int
# '0'=====str
#
# 0 is empty OFF   FLASE
# '0' is one character is available ture

# %%
n1='100'
len(n1)
bool(len(n1))
# Out:
# True

# %% [markdown]
# int('100.5')  # error
# int('100')    # 100
#
# int('100.5')  vs int(100.5)
# bool('0')     vs bool(0)

# %% [markdown]
# **bool to other**

# %%
int(True)
# Out:
# 1

# %%
float(True)
# Out:
# 1.0

# %%
str('True')
# Out:
# 'True'

# %%
float(100)
str(100)
bool(100)
int(100.5)
bool(0)
int('apple')
float('apple')
bool('100')
bool('0')

# %%
n1=int(input('enter the n1:')) #n1=int('100')=100
n2=int(input('enter the n2:')) #n2=int('200')=200
n1+n2   #n1+n2=100+200=300
# Out:
# enter the n1: 100
# enter the n2: 200
# 300

# %%
n1=int(input('enter the n1:')) 
n2=float(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 100.5
# 200.5

# %%
n1=int(input('enter the n1:')) 
n2=int(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 0
# 100

# %% [markdown]
# - whenever we want to use interger then we are applying **int**
#
# - similarly if we want to use decimal number we are applying **float**
#
# - there is one more operation is the : **eval**
#
# - **eval** will convert integer values to int type, decimal values to float type

# %%
n1=int(input('enter the n1:')) 
n2=eval(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 200.5
# 300.5

# %%
n1=eval(input('enter the n1:')) # instead of int and float we applying eval
n2=eval(input('enter the n2:'))
n1+n2
# Out:
# enter the n1: 100
# enter the n2: 100.5
# 200.5

# %%
# overage of 3 numbers
n1=eval(input('enter the n1:')) 
n2=eval(input('enter the n2:'))
n3=eval(input('enter the n3:'))
n1+n2+n3/3
# Out:
# enter the n1: 10
# enter the n2: 20
# enter the n3: 30.30
# 40.1

# %%
# wap ask the user take two number print subtraction multiplication and division
# ans: the subtraction of 100 and 200 is -100
#      the multiplication of 100 and 200 is 20000
#      the division of 100 and 200 is 0.5

# wap ask the user take the radius find the area of circle
    # pi=3.14
    # r=100
   # area_of_circle=pi*r*r

# wap ask the user take height and breadth find the area of traingle
#       area_of_traingle=0.5*b*h

# wap ask the user take 3 numbers find the average
# wap ask the user take the bill amount and tip amount calculate total bill
# wap ask the user take the salary, percetage of tax calculate tax amount
#      tax_amount= salary*tax_per/100
# wap ask the use take weight in kgs convert into pounds
#     1kg=2.2pounds

# %%
n1=eval(input('enter the n1:')) 
n2=eval(input('enter the n2:'))
sub=n1+n2
sub
# Out:
# enter the n1: 100
# enter the n2: -200
# -100

# %%
#  the multiplication of 100 and 200 is 20000
n1=eval(input('enter the n1:')) 
n2=eval(input('enter the n2:'))
mul=n1*n2
mul
# Out:
# enter the n1: 100
# enter the n2: 200
# 20000

# %%
n1=eval(input('enter the n1:')) 
n2=eval(input('enter the n2:'))
div=n1/n2
div
# Out:
# enter the n1: 100
# enter the n2: 200
# 0.5

# %%
# wap ask the user take the radius find the area of circle
    # pi=3.14
    # r=100
   # area_of_circle=pi*r*r
pi=eval(input('3.14'))
r=eval(input('100'))
area_of_circle=pi*r*r
area_of_circle
# Out:
# 3.14 3.14
# 100 100
# 31400.0

# %%
# wap ask the user take height and breadth find the area of traingle
#       area_of_traingle=0.5*b*h
height=eval(input('height'))
breadth=eval(input('breadth'))
area_of_triangle=0.5*breadth*height
area_of_triangle
# Out:
# height 70
# breadth 50
# 1750.0

# %%
# wap ask the user take 3 numbers find the average

n1=eval(input('enter the value:'))
n2=eval(input('enter the value:'))
n3=eval(input('enter the value:'))
n1+n2+n3/3
# Out:
# enter the value: 100
# enter the value: 200
# enter the value: 300
# 400.0

# %%
# wap ask the user take the bill amount and tip amount calculate total bill

n1=eval(input('bill_amount:'))
n2=eval(input('tip_amount:'))
total_bill=n1+n2
total_bill
# Out:
# bill_amount: 5000
# tip_amount: 200
# 5200

# %%
# wap ask the user take the salary, percetage of tax calculate tax amount
        #tax_amount= salary*tax_per/100

n1=eval(input('salary:'))
n2=eval(input('percentage_of_tax:'))
tax_amount=salary*percentage_of_tax/100
print(f'the total amount salary is:{tax_amount}')

# %%
# wap ask the use take weight in kgs convert into pounds
#     1kg=2.2pounds

kg = float(input("Enter weight in kilograms: "))
pounds = kg * 2.2
print(f"{kg} kg is equal to {pounds} pounds")
# Out:
# Enter weight in kilograms:  2
# 2.0 kg is equal to 4.4 pounds
