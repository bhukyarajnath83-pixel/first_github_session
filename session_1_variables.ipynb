# %% [markdown]
# **name error
#
# - you did not defined/initialized/exceuted
#
# - but you are trying

# %%
NUMBER=100
NUMBER
# Out:
# 100

# %%
number=200
number=200

# %%
NUMBER,number
# Out:
# (100, 200)

# %%
NUMber=400
NUMber
# Out:
# 400

# %%
number123=600
number123
# Out:
# 600

# %%
123number=700
123number
# Out:
#   Cell In[20], line 1
#     123number=700
#       ^
# SyntaxError: invalid decimal literal

# %%
NUM@ber=200
num@ber # special characters are not allowed
# Out:
#   Cell In[22], line 1
#     NUM@ber=200
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
$number=100
$number # special character are not allowed
# Out:
#   Cell In[23], line 1
#     $number=100
#     ^
# SyntaxError: invalid syntax

# %%
num_ber=200
num_ber # _ is a special character
# Out:
# 200

# %%
num@ber=200 # f
$number=100 # f
num_ber=200 # w
areaofcircle=300 # w
area_of_circle=400 # w
area of circle=500 # f

# %%
_=500
_
# Out:
# 500

# %%
if=500
if
# Out:
#   Cell In[31], line 1
#     if=500
#       ^
# SyntaxError: invalid syntax

# %%
sum=500
sum
# Out:
# 500

# %% [markdown]
# sum is a math family===>
# max is a math family===>
# min is a math family===>
# len is a math family

# %%
l=[1,2,3,4,]
sum(l)
# Out:
# 10

# %%
print(l)
# Out:
# [1, 2, 3, 4]

# %%
type(l)
# Out:
# list

# %%
max(l)
# Out:
# 4

# %%
min(l)
# Out:
# 1

# %%
len(l)
# Out:
# 4

# %% [markdown]
# - variables can be capital and small lettrs
#
# - variables are case sensitive
#
# - variables does not include spl characters
#
# - Numbers as prefix not allowed
#
# - variables can have underscore
#
# - only underscore also possible
#
# - reserved or keywords can not be variable
#
# - inbuilt functions can not use as variable
