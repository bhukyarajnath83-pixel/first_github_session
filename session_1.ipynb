# %% [markdown]
# # python
# ## python
# ### python

# %%
![ai image](![image.png](attachment:62135b88-295f-4401-be3d-841c0ff16202.png)
# Out:
# '[ai' is not recognized as an internal or external command,
# operable program or batch file.
