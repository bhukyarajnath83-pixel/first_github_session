# %%
- python kernel
- your servent

- we will write the python code : kernel will execute it 
- we will one work maid :he will execute

- kernel: computational engine 

- kernel : white ======idle state =======> ready to take work
       : black ======busy state =======> already doing work 
         condition :we shouldb not give any other work
       : red =======die state =======> kernel dead
-reset the kernel

# %%
for i in range(100):
    pass

# %%
import time
time.sleep(5)
print('hai')

# %%
a=10
print(a)

# %% [markdown]
# - start mark indicate that kernel is busy
#
# - do not run any cell

# %%
a=10

# %%
b=20

# %%
a+b

# %%
number=10000

# %%
number

# %% [markdown]
# - python is a step by step process
#
# - if we write 10 lines
#
# - all 10 lines python execute one by one
#
# - even it is one cell has 10 lines
#
# - you can write 10 lines in different 10cells

# %%
import os
os.getcwd()  
# current working directory
# we can able to see where is the python file available in my laptop
# Out:
# 'C:\\Users\\Bhukya Rajnath\\OneDrive\\Documents\\Naresh IT'

# %%
c:\\users\\Bhukya Rajnath\\<python>
