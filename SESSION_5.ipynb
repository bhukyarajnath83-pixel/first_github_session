# %% [markdown]
# **covered syllabus**
#
# - variables
#
# - data types
#
# - type casting
#
# - print statement
#
# - input and round
#
# - we perform basic codes 3 ways
#    - using proper variable
#    - using print statement
#    - using input and round

# %%
**packages**

# ramesh is a very good student 

# he created a python code which do the addition of two numbers

# ramesh felt that this code no one created tiil now

# he decided he wants to handover that to entier world

# he approached anaconda organization

# my code should download autometically

# agreement
# Out:
#   Cell In[1], line 1
#     **packages**
#     ^
# SyntaxError: invalid syntax

# %%
import random

# %%
import math

# %%
import time

# %%
import os

# %%
import cv2

# %%
import virat

# %%
# ramesh is so super exited
# he created subtraction,division,multiplication
# Anaconda is asking that handover that codes
# what are the ways to handover
  #method_1
  #addition 
  #sub
  #mul
  #div

# %% [markdown]
# **Modules**
#
# - Modules is a single python file
#
# - Having varibables,functions,classes,methods
#
# **packages**
#
# - packages contain multiple python files
#
# - assum that ramesh has created 4 python files
#
#       - add.py
#
#       - sub.py
#
#       - mul.py
#
#       - div.py
#
# - All these 4 python files can save into a package

# %%
math_functions/
 add.py
 sub.py
 mul.py
 div.py

from math_functions import add

from math_function import sub

from math_function import mul

from math_funmction import div

# %%
 - every python file can be consider as module

- every modules has

  - varibales
  - function

     - some times we write these function under the **class**

     - if a function is writting the class we called **method**

# %% [markdown]
# **random**

# %%
import random
dir(random)

# %%
# step-1: import module name 
# step-2: dir(<module name>) #dir means directory

# %%
import math
dir(math)

# %%
import time
dir(time)

# %%
import os
dir(os)

# %%
import random
dir(ramdon) # correct # dir is used for to find how many methods

import <random>
import(import random)#wrong

# %% [markdown]
# *Methos under a module also called as attributes**
#
# - random is module
#
#     - randint is a method or attribute
#
#     - random is a method or attribute
#
# - Every method purpose or use case id different
#
# - IF we want call method ot attribute ,we need to call using module

# %%
import random
random.randint

# attribte ,randit available 
# i missed the bracket then bound method is coming

# %%
import random
random.virat
# not attribute name virat

# %%
dir(random)

# %%
import random
randit.randintt
# AttributeError: module 'random' has no attribute'randintt'

# %%
# step-1: import< module name >
# step-2: dir(<module_name>)
# step-3: module_name.method_name
#when we do step-3 some times
#       we will get answer
#       we will get a indication
#         bound method or function

# %%
import random
#dir(random)
random.randint

# %%
# what will the works randit will do?
help(random.randint)

# %%
random.randint(1,10)

# %%
# step-1 :import modulenam
#step-

# %%
import random
dir(random)
random.randint
help(random.randint)
random.randint(1,10)

# %%
import random
dir(random)
random.random
help(random.random)
random.random()

# %%
import random
dir(random)
random.random
help(random.random)
random.random()

# %%
import random
dir(random)
random.randint
help(random.randint)
random.randint(1,10)

# %%
import time
dir(time)

# %%
import random
dir(random)
help (random.randint)

# %%
random.randint()

# %%
random.randint(10)

# %%
random.randint(1,10)

# %%
#module       method
# random     random
#random      choice
# random     shuffle          
#random      e
#math        pi
#math        sqrt
#math       pow
# math      sin
#math       ceil
#time      sleep
#os         getcwd
#os         listdir


l=[10,20,30,40,50]
random.choice(l)

# %%
import random
dir(random)
random.choice
help(random.choice)
l=1,2,3,4,5
random.choice(l)
print(l)

# %%
import random
dir(random)
random.shuffle
help(random.shuffle)
x=[10,20,30,40]
random.shuffle(x)
print(x)
# Out:
# Help on method shuffle in module random:
#
# shuffle(x) method of random.Random instance
#     Shuffle list x in place, and return None.
#
# [40, 10, 20, 30]

# %%
import math
dir(math)
math.e
a=float('20.5253488')
round(a)

# %%
import math
dir(math)
math.pi

# %%
import math
dir(math)
math.sqrt
help(math.sqrt)
math.sqrt(7)

# %%
import math
dir(math)
math.pow
help(math.pow)
math.pow(5,7)

# %%
l=20
math.sin(l)
l

# %%
math.ceil(40.6789)

# %%
import time
start=time.time()
dir(time)
time.sleep(10)
print('good evening')
end=time.time()
end-start
# Out:
# good evening
# 10.00105881690979

# %%
start=time.time()
time.sleep(5)
print('rajnath')
end=time.time()
end-start
# Out:
# rajnath
# 5.001439571380615

# %%
import os
dir(os)
os.getcwd()
# Out:
# 'C:\\Users\\Bhukya Rajnath\\OneDrive\\Documents\\Naresh IT'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'practice_2.ipynb',
#  'practice_session_1.ipynb',
#  'session_1.ipynb',
#  'session_1_variables.ipynb',
#  'session_2 data types.ipynb',
#  'session_2.ipynb',
#  'SESSION_5.ipynb',
#  'variable Q&A.ipynb']

# %%
import os
dir(os)
os.makedirs
# Out:
# <function os.makedirs(name, mode=511, exist_ok=False)>

# %%
import keyword
dir(keyword)
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
# WE understood the module and packages
# We understood the difference between
   # functions and methods
#

# %%
import string
dir(string)
# Out:
# ['Formatter',
#  'Template',
#  '_ChainMap',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_re',
#  '_sentinel_dict',
#  '_string',
#  'ascii_letters',
#  'ascii_lowercase',
#  'ascii_uppercase',
#  'capwords',
#  'digits',
#  'hexdigits',
#  'octdigits',
#  'printable',
#  'punctuation',
#  'whitespace']

# %%
import string
dir(string)
string.Template
# Out:
# string.Template

# %%
import string
dir(string)
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.capwords
help(string.capwords)
string
# Out:
# Help on function capwords in module string:
#
# capwords(s, sep=None)
#     capwords(s [,sep]) -> string
#
#     Split the argument into words using split, capitalize each
#     word using capitalize, and join the capitalized words using
#     join.  If the optional second argument sep is absent or None,
#     runs of whitespace characters are replaced by a single space
#     and leading and trailing whitespace are removed, otherwise
#     sep is used to split and join the words.

# %%
string.digits
# Out:
# '0123456789'

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
string.printable
# Out:
# '0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~ \t\n\r\x0b\x0c'

# %%
string.whitespace
# Out:
# ' \t\n\r\x0b\x0c'

# %%
import random
random.randint(10,20)
# Out:
# 16

# %%
from random import randint
randint(10,20)
# Out:
# 13

# %%
import random
random
# Out:
# <module 'random' from 'C:\\Users\\Bhukya Rajnath\\anaconda3\\Lib\\random.py'>

# %%
import flask

# %%
import streamlit

# %%
import cv2

# %%
import langchain

# %%
import sachin
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 import sachin
#
# ModuleNotFoundError: No module named 'sachin'

# %%
import langchain

# %%
ModuleNotFoundError: No module named 'cv2'

# %%
import cv2

# %%
import cv2
dir(cv2)
cv2.accumulate
# Out:
# <function accumulate>

# %%
import langchain
dir(langchain)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__']

# %%
import langgraph

# %%
import tensorflow
dir(tensorflow)
# Out:
# ['AggregationMethod',
#  'Assert',
#  'CriticalSection',
#  'DType',
#  'DeviceSpec',
#  'GradientTape',
#  'Graph',
#  'IndexedSlices',
#  'IndexedSlicesSpec',
#  'Module',
#  'Operation',
#  'OptionalSpec',
#  'RaggedTensor',
#  'RaggedTensorSpec',
#  'RegisterGradient',
#  'SparseTensor',
#  'SparseTensorSpec',
#  'Tensor',
#  'TensorArray',
#  'TensorArraySpec',
#  'TensorShape',
#  'TensorSpec',
#  'TypeSpec',
#  'UnconnectedGradients',
#  'Variable',
#  'VariableAggregation',
#  'VariableSynchronization',
#  '_API_MODULE',
#  '_KerasLazyLoader',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__compiler_version__',
#  '__cxx11_abi_flag__',
#  '__cxx_version__',
#  '__doc__',
#  '__file__',
#  '__git_version__',
#  '__internal__',
#  '__loader__',
#  '__monolithic_build__',
#  '__name__',
#  '__operators__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_api',
#  '_compat',
#  '_current_file_location',
#  '_current_module',
#  '_fi',
# ...
